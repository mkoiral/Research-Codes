# %%
pwd
# Out:
# '/Users/maheshkoirala/Desktop/data'

# %%
import pandas as pd

# %%
data1 = 'exel1.xls'
data2 = 'exel2.xls'

# %%
df1 = pd.read_excel(data1)
df2= pd.read_excel(data2)

# %%
value1 = df1[['Name', 'Email', 'PCQ-1', 'PCQ-2', 'PCQ-3','PCQ-4', 'PCQ-5', 'PCQ-6', 'PCQ-7']]

# %%
value2 = df2[['Name', 'Email', 'PCQ-1', 'PCQ-2', 'PCQ-3','PCQ-4', 'PCQ-5', 'PCQ-6', 'PCQ-7']]

# %%
dataframes = [value1, value2]

# %%
pd.concat(dataframes)
# Out:
#                      Name                  Email           PCQ-1  \
# 0          Alford, Justin    jbalfor@clemson.edu              20
# 1           Alquza, Ahmad  aalquza@g.clemson.edu              20
# 2        Anderson, Robert    rzander@clemson.edu              20
# 3            Anker, Mason     manker@clemson.edu              20
# 4           Axness, Ethan    eaxness@clemson.edu              18
# 5           Bach, Stephen    sbach@g.clemson.edu              20
# 6         Barber, Charles  cfbarbe@g.clemson.edu              20
# 7        Barks, Alexander     abarks@clemson.edu              20
# 8        Battles, Richard    rjbattl@clemson.edu              20
# 9          Beyer, Jackson   jbeyer@g.clemson.edu              20
# 10          Bishop, Jacob  jbisho9@g.clemson.edu              18
# 11            Black, Owen    ofblack@clemson.edu              20
# 12        Blalock, Andrew  ajblalo@g.clemson.edu              14
# ...

# %%
dataframes
# Out:
# [                           Name                  Email           PCQ-1  \
#  0                Alford, Justin    jbalfor@clemson.edu              20
#  1                 Alquza, Ahmad  aalquza@g.clemson.edu              20
#  2              Anderson, Robert    rzander@clemson.edu              20
#  3                  Anker, Mason     manker@clemson.edu              20
#  4                 Axness, Ethan    eaxness@clemson.edu              18
#  5                 Bach, Stephen    sbach@g.clemson.edu              20
#  6               Barber, Charles  cfbarbe@g.clemson.edu              20
#  7              Barks, Alexander     abarks@clemson.edu              20
#  8              Battles, Richard    rjbattl@clemson.edu              20
#  9                Beyer, Jackson   jbeyer@g.clemson.edu              20
#  10                Bishop, Jacob  jbisho9@g.clemson.edu              18
#  11                  Black, Owen    ofblack@clemson.edu              20
# ...

# %%
output = pd.concat(dataframes)

# %%
output
# Out:
#                      Name                  Email           PCQ-1  \
# 0          Alford, Justin    jbalfor@clemson.edu              20
# 1           Alquza, Ahmad  aalquza@g.clemson.edu              20
# 2        Anderson, Robert    rzander@clemson.edu              20
# 3            Anker, Mason     manker@clemson.edu              20
# 4           Axness, Ethan    eaxness@clemson.edu              18
# 5           Bach, Stephen    sbach@g.clemson.edu              20
# 6         Barber, Charles  cfbarbe@g.clemson.edu              20
# 7        Barks, Alexander     abarks@clemson.edu              20
# 8        Battles, Richard    rjbattl@clemson.edu              20
# 9          Beyer, Jackson   jbeyer@g.clemson.edu              20
# 10          Bishop, Jacob  jbisho9@g.clemson.edu              18
# 11            Black, Owen    ofblack@clemson.edu              20
# 12        Blalock, Andrew  ajblalo@g.clemson.edu              14
# ...

# %%
output.to_excel("output.xls")

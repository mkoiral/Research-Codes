# %%
#2 OCA2 here we make zero at pH3. fo this we add ofset at pH=3 for each point.
import pandas as pd
import numpy as np
from scipy.interpolate import spline
from matplotlib import pyplot as plt
plt.style.use('seaborn') 
import warnings 
import statistics
import matplotlib 
matplotlib.rc('xtick', labelsize=15)     
matplotlib.rc('ytick', labelsize=15)
warnings.filterwarnings('ignore') 
warnings.simplefilter('ignore') 

sample_data = pd.read_csv('OCA2_MD.csv') 
plt.axis([4, 8, -10, 1]) 
#plt.axis([4, 8, -60,20]) 
x = sample_data.pH 
y2ph = sample_data.DGWT[8] 
y2 = sample_data.DGWT-y2ph


y3ph = sample_data.DGA481T[8] 
y3 = sample_data.DGA481T-y3ph+0.52

y4ph = sample_data.DGH615L[8] 
y4 = sample_data.DGH615L-y4ph+0.39

y5ph = sample_data.DGN489D[8] 
y5 = sample_data.DGN489D-y5ph+1.05

y6ph = sample_data.DGP743L[8] 
y6 = sample_data.DGP743L-y6ph+0.45

y7ph = sample_data.DGR419Q[8] 
y7 = sample_data.DGR419Q-y7ph+0.33

y8ph = sample_data.DGV443I[8] 
y8 = sample_data.DGV443I-y8ph+0.48


pH = np.linspace(x.min(), x.max(), 500)

#TYR = spline(x, y1, pH) 
WT= spline(x, y2, pH) 
A418T = spline(x, y3, pH) 
H615R = spline(x, y4, pH) 
N489D = spline(x, y5, pH) 
P743L = spline(x, y6, pH) 
R419Q = spline(x, y7, pH) 
V443I = spline(x, y8, pH)


#plt.scatter(x, y1, color='black', label="", marker="x") 
plt.scatter(x, y2, color='blue', label="WT", marker="o") 
plt.scatter(x, y3, color='orange', label="A481T", marker="*") 
plt.scatter(x, y4, color='green', label="H615L", marker="^") 
plt.scatter(x, y5, color='brown', label="N489D", marker="d") 
plt.scatter(x, y6, color='red', label="P743L", marker="+") 
plt.scatter(x, y7, color='black', label="R419Q", marker="s") 
plt.scatter(x, y8, color='purple', label="V443I", marker="x")


#plt.plot(pH, WT, color='b', marker='d', label="WT",markersize=1) 
plt.plot(pH, WT, color='blue', marker='', label="",markersize=1) 
plt.plot(pH, A418T, color='orange', marker='', label="",markersize=1) 
plt.plot(pH, H615R, color='green', marker='', label="",markersize=1) 
plt.plot(pH, N489D, color='brown', marker='', label="",markersize=1) 
plt.plot(pH, P743L, color='red', marker='', label="",markersize=1) 
plt.plot(pH, R419Q, color='black', marker='', label="",markersize=1) 
plt.plot(pH, V443I, color='purple', marker='', label="",markersize=1)


plt.title('OCA2', fontsize=15, color='black') 
plt.xlabel('pH', color='black', fontsize=15) 
plt.ylabel('Free energy (folded-unfolded) [kcal/mol]', color='black', fontsize=15) 
plt.legend(loc='top', ncol=1,fontsize=15)
#plt.legend(loc='center left', ncol=4, bbox_to_anchor=(0.05, 0.1), fontsize=15)
plt.grid(linestyle='-', linewidth='0.5') 
plt.savefig('MD_DG-pH4-8+AVG+offset_oca2.png', dpi=800)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-85-022600eb509d> in <module>()
#      13 warnings.simplefilter('ignore')
#      14
# ---> 15 sample_data = pd.read_csv('OCA2_MD.csv')
#      16 plt.axis([4, 8, -10, 1])
#      17 #plt.axis([4, 8, -60,20])
#
# ...

# %%
 #TPC2 here we make zero at pH3. for this we add offset at pH=4 for each point.
import pandas as pd
import numpy as np
from scipy.interpolate import spline
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('seaborn') 
import warnings 
import statistics
import matplotlib 
matplotlib.rc('xtick', labelsize=15)     
matplotlib.rc('ytick', labelsize=15)
warnings.filterwarnings('ignore') 
warnings.simplefilter('ignore') 


sample_data = pd.read_csv('MD_DG-tpc2.csv') 
plt.axis([4, 8, -25, 1])

#plt.axis([4, 8, -130, 10]) 
x = sample_data.pH 
y2ph = sample_data.DGWT[8] 
y2 = sample_data.DGWT-y2ph


y3ph = sample_data.DGK376R[8] 
y3 = sample_data.DGK376R-y3ph+0.49

y4ph = sample_data.DGM484L[8] 
y4 = sample_data.DGM484L-y4ph+0.86

y5ph = sample_data.DGM546I[8] 
y5 = sample_data.DGM546I-y5ph+0.1

y6ph = sample_data.DGV219I[8] 
y6 = sample_data.DGV219I-y6ph+0.11


pH = np.linspace(x.min(), x.max(), 500)

#TPC2 = spline(x, y1, pH) 
WT= spline(x, y2, pH) 
K376R = spline(x, y3, pH) 
M484L = spline(x, y4, pH) 
M546I = spline(x, y5, pH) 
V219I = spline(x, y6, pH) 


#plt.scatter(x, y1, color='black', label="", marker="x") 
plt.scatter(x, y2, color='blue', label="WT", marker="o") 
plt.scatter(x, y3, color='orange', label="K376R", marker="*") 
plt.scatter(x, y4, color='green', label="M484L", marker="^") 
plt.scatter(x, y5, color='brown', label="M546I", marker="d") 
plt.scatter(x, y6, color='red', label="V219I", marker="+") 

#plt.plot(pH, WT, color='b', marker='d', label="WT",markersize=1) 
plt.plot(pH, WT, color='blue', marker='', label="",markersize=1) 
plt.plot(pH, K376R, color='orange', marker='', label="",markersize=1) 
plt.plot(pH, M484L, color='green', marker='', label="",markersize=1) 
plt.plot(pH, M546I, color='brown', marker='', label="",markersize=1) 
plt.plot(pH, V219I, color='red', marker='', label="",markersize=1) 


plt.title('TPC2', fontsize=15, color='black') 
plt.xlabel('pH', color='black', fontsize=15) 
plt.ylabel('Free energy (folded-unfolded) [kcal/mol]', color='black', fontsize=15) 
plt.legend(loc='right', ncol=1,fontsize=15)
#plt.legend(loc='center left', ncol=4, bbox_to_anchor=(0.05, 0.1), fontsize=15)
plt.grid(linestyle='-', linewidth='0.5') 
plt.savefig('MD_DG-pH4-8+AVG+offset_tpc2.png', dpi=800)

plt.show()

# %% [markdown]
# 2 OCA2 here we make zero at pH3. fo this we add ofset at pH=3 for each point.
# import pandas as pd
# import numpy as np
# from scipy.interpolate import spline
# from matplotlib import pyplot as plt
# plt.style.use('ggplot')
# import warnings
# warnings.filterwarnings('ignore')
# warnings.simplefilter('ignore')
# sample_data = pd.read_csv('oca2_Dq_DG.csv')
# plt.axis([3, 8, -25, 2])
# x = sample_data.pH
# y2ph = sample_data.DGWT[6]
# y2 = sample_data.DGWT-y2ph
#
# y3ph = sample_data.DGA418T[6]
# y3 = sample_data.DGA418T-y3ph
#
# y4ph = sample_data.DGH615R[6]
# y4 = sample_data.DGH615R-y4ph
#
# y5ph = sample_data.DGN489D[6]
# y5 = sample_data.DGN489D-y5ph
#
# y6ph = sample_data.DGP743L[6]
# y6 = sample_data.DGP743L-y6ph
#
# y7ph = sample_data.DGR419Q[6]
# y7 = sample_data.DGR419Q-y7ph
#
# y8ph = sample_data.DGV443I[6]
# y8 = sample_data.DGV443I-y8ph
#
# pH = np.linspace(x.min(), x.max(), 500)
#
# #TYR = spline(x, y1, pH)
# WT= spline(x, y2, pH)
# A418T = spline(x, y3, pH)
# H615R = spline(x, y4, pH)
# N489D = spline(x, y5, pH)
# P743L = spline(x, y6, pH)
# R419Q = spline(x, y7, pH)
# V443I = spline(x, y8, pH)
#
#
# #plt.plot(pH, WT)
# #plt.scatter(x, y1,  color='black', label="", marker="x")
# plt.scatter(x, y2,  color='black', label="", marker="o")
# plt.scatter(x, y3,  color='black', label="", marker="*")
# plt.scatter(x, y4,  color='black', label="", marker="^")
# plt.scatter(x, y5,  color='black', label="", marker="+")
# plt.scatter(x, y6,  color='black', label="", marker="+")
# plt.scatter(x, y7,  color='black', label="", marker="v")
# plt.scatter(x, y8,  color='black', label="", marker="x")
#
#
#
# #plt.plot(pH, WT, color='b', marker='d', label="WT",markersize=1)
# plt.plot(pH, WT, 'b-d', label="WT",markersize=1)
# plt.plot(pH, A418T, color='orange', marker='o', label="A418T",markersize=1)
# plt.plot(pH, H615R, color='green', marker='*', label="H615R",markersize=1)
# plt.plot(pH, N489D, color='brown', marker='^', label="N489D",markersize=1)
# plt.plot(pH, P743L, color='red', marker='+', label="P743L",markersize=1)
# plt.plot(pH, R419Q, color='black', marker='v', label="R419Q",markersize=1)
# plt.plot(pH, V443I, color='purple', marker='x', label="V443I",markersize=1)
#
#
# plt.title('OCA2', fontsize=15)
# plt.xlabel('pH')
# plt.ylabel('Free energy (folded-unfolded) [kcal/mol]')
# plt.legend(loc='center left', ncol=2, bbox_to_anchor=(0.5, 0.8))
# #plt.legend(handles=z1,loc='lower right', bbox_to_anchor=(0.7, 0.8))
# plt.grid(linestyle='-', linewidth='0.5', color='black')
# plt.savefig('DG-pH3-8+offset_oca2.png', dpi=800)
#
# plt.show()

# %%
 #SLC45A2 here we make zero at pH3. for this we add offset at pH=4 for each point.
import pandas as pd
import numpy as np
from scipy.interpolate import spline
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('seaborn') 
import warnings 
import statistics
import matplotlib 
matplotlib.rc('xtick', labelsize=15)     
matplotlib.rc('ytick', labelsize=15)
warnings.filterwarnings('ignore') 
warnings.simplefilter('ignore') 


sample_data = pd.read_csv('MD_DG-slc45a2.csv') 
plt.axis([4, 8, -12,1])

#plt.axis([4, 8, -130, 10]) 
x = sample_data.pH 
y2ph = sample_data.DGWT[8] 
y2 = sample_data.DGWT-y2ph

y3ph = sample_data.DGG198V[8] 
y3 = sample_data.DGG198V-y3ph+0.51

y4ph = sample_data.DGL374F[8] 
y4 = sample_data.DGL374F-y4ph+0.84


pH = np.linspace(x.min(), x.max(), 500)

#SLC45A2 = spline(x, y1, pH) 
WT= spline(x, y2, pH) 
G198V = spline(x, y3, pH) 
L374F = spline(x, y4, pH) 


#plt.scatter(x, y1, color='black', label="", marker="x") 
plt.scatter(x, y2, color='blue', label="WT", marker="o") 
plt.scatter(x, y3, color='orange', label="G198V", marker="*") 
plt.scatter(x, y4, color='green', label="L374F", marker="^") 

#plt.plot(pH, WT, color='b', marker='d', label="WT",markersize=1) 
plt.plot(pH, WT, color='blue', marker='', label="",markersize=1) 
plt.plot(pH, G198V, color='orange', marker='', label="",markersize=1) 
plt.plot(pH, L374F, color='green', marker='', label="",markersize=1) 

plt.title('SLC45A2', fontsize=15, color='black') 
plt.xlabel('pH', color='black', fontsize=15) 
plt.ylabel('Free energy (folded-unfolded) [kcal/mol]', color='black', fontsize=15) 
plt.legend(loc='top', ncol=1,fontsize=15)
#plt.legend(loc='center left', ncol=4, bbox_to_anchor=(0.05, 0.1), fontsize=15)
plt.grid(linestyle='-', linewidth='0.5') 
plt.savefig('MD_DG-pH4-8+AVG+offset_slc45a2.png', dpi=800)

plt.show()

# %%
# 4 ATP7A here we make zero at pH3. fo this we add ofset at pH=3 for each point. 
import pandas as pd
import numpy as np
from scipy.interpolate import spline
from matplotlib import pyplot as plt
plt.style.use('seaborn') 
import warnings 
import statistics
import matplotlib 
matplotlib.rc('xtick', labelsize=15)     
matplotlib.rc('ytick', labelsize=15)
warnings.filterwarnings('ignore') 
warnings.simplefilter('ignore') 

sample_data = pd.read_csv('ATP7A_MD.csv')
plt.axis([4, 8, -20, 2])
x = sample_data.pH
y2ph = sample_data.DGWT[8]
#print(y2ph)
y2 = sample_data.DGWT-y2ph

y3ph = sample_data.DGC1002F[8]
y3 = sample_data.DGC1002F-y3ph+1.2

y4ph = sample_data.DGD1044E[8]
y4 = sample_data.DGD1044E-y4ph+0.21

y5ph = sample_data.DGG666R[8]
y5 = sample_data.DGG666R-y5ph+0.8

y6ph = sample_data.DGI1264V[8]
y6 = sample_data.DGI1264V-y6ph+1.1

y7ph = sample_data.DGK742R[8]
y7 = sample_data.DGK742R-y7ph+0.01

y8ph = sample_data.DGM1311V[8]
y8 = sample_data.DGM1311V-y8ph+0.79

y9ph = sample_data.DGR844C[8]
y9 = sample_data.DGR844C-y9ph+0.48

y10ph = sample_data.DGS653Y[8]
y10 = sample_data.DGS653Y-y10ph+0.45

pH = np.linspace(x.min(), x.max(), 500)  

#TYR = spline(x, y1, pH)
WT= spline(x, y2, pH)
C1002F = spline(x, y3, pH)
D1044E = spline(x, y4, pH)
G666R = spline(x, y5, pH)
I1264V = spline(x, y6, pH)
K742R = spline(x, y7, pH)
M1311V = spline(x, y8, pH)
R844C = spline(x, y9, pH)
S653Y = spline(x, y10, pH)


#plt.plot(pH, WT)
#plt.scatter(x, y1,  color='black', label="", marker="x")
plt.scatter(x, y2,  color='blue', label="WT", marker="o")
plt.scatter(x, y3,  color='orange', label="C1002F", marker="*")
plt.scatter(x, y4,  color='green', label="D1044E", marker="^")
plt.scatter(x, y5,  color='brown', label="G666R", marker="+")
plt.scatter(x, y6,  color='red', label="I1264V", marker="d")
plt.scatter(x, y7,  color='black', label="K742R", marker="s")
plt.scatter(x, y8,  color='purple', label="M1311V", marker="p")


#plt.plot(pH, TYR, color='red', marker='.', label="TYR",markersize=1)
plt.plot(pH, WT, color='blue', marker='', label="",markersize=1)
plt.plot(pH, C1002F, color='orange', marker='.', label="",markersize=1)
plt.plot(pH, D1044E, color='green', marker='.', label="",markersize=1)
plt.plot(pH, G666R, color='brown', marker='.', label="",markersize=1)
plt.plot(pH, I1264V, color='red', marker='.', label="",markersize=1)
plt.plot(pH, K742R, color='black', marker='.', label="",markersize=1)
plt.plot(pH, M1311V, color='purple', marker='.', label="",markersize=1)
plt.plot(pH, R844C, color='yellow', marker='.', label="",markersize=1)
plt.plot(pH, S653Y, color='olive', marker='.', label="",markersize=1)

plt.title('ATP7A', fontsize=15)
plt.xlabel('pH', color='black', fontsize=15)
plt.ylabel('Free energy (folded-unfolded) [kcal/mol]', color='black', fontsize=15)
plt.legend(loc='top' ,ncol=1, fontsize=15)
plt.grid(linestyle='-', linewidth='0.5')
plt.savefig('MD_DG-pH4-8+AVG+offset_atp7a.png', dpi=800)

plt.show()

# %%
# 5 TYR here we make zero at pH3. fo this we add ofset at pH=3 for each point. 
import pandas as pd
import numpy as np
from scipy.interpolate import spline
from matplotlib import pyplot as plt
plt.style.use('seaborn') 
import warnings 
import statistics
import matplotlib 
matplotlib.rc('xtick', labelsize=15)     
matplotlib.rc('ytick', labelsize=15)
warnings.filterwarnings('ignore') 
warnings.simplefilter('ignore') 
sample_data = pd.read_csv('TYR_MD.csv')
plt.axis([4, 8, -35, 1])
x = sample_data.pH
y2ph = sample_data.DGWT[8]
#print(y2ph)
y2 = sample_data.DGWT-y2ph

y3ph = sample_data.DGR402Q[8]
y3 = sample_data.DGR402Q-y3ph+0.5

y4ph = sample_data.DGS192Y[8]
y4 = sample_data.DGS192Y-y4ph+0.27



pH = np.linspace(x.min(), x.max(), 500)  

#TYR = spline(x, y1, pH)
WT= spline(x, y2, pH)
R402Q = spline(x, y3, pH)
S192Y = spline(x, y4, pH)


#plt.plot(pH, WT)
#plt.scatter(x, y1,  color='black', label="", marker="x")
plt.scatter(x, y2,  color='blue', label="WT", marker="o")
plt.scatter(x, y3,  color='orange', label="R402Q", marker="*")
plt.scatter(x, y4,  color='green', label="S192Y", marker="d")


#plt.plot(pH, TYR, color='red', marker='.', label="TYR",markersize=1)
plt.plot(pH, WT, color='blue', marker='', label="",markersize=1)
plt.plot(pH, R402Q, color='orange', marker='.', label="",markersize=1)
plt.plot(pH, S192Y, color='green', marker='.', label="",markersize=1)

plt.title('TYR', fontsize=15)
plt.xlabel('pH', color='black', fontsize=15)
plt.ylabel('Free energy (folded-unfolded) [kcal/mol]', color='black', fontsize=15)
plt.legend(loc='top', fontsize=15)
plt.grid(linestyle='-', linewidth='0.5')
plt.savefig('MD_DG-pH4-8+AVG+offset_tyr.png', dpi=800)

plt.show()

# %%
#
